# %%
import numpy as np
from astropy.io import fits
import matplotlib.pyplot as plt

# %%
# ALMA image
fits_image = "../ALMA/cleanmap/R0600-ID67_T1_clean.image.fits"
fits_psf   = "../ALMA/cleanmap/R0600-ID67_T1.psf.fits"

image = fits.getdata(fits_image)
psf = fits.getdata(fits_psf)

plt.imshow(image)
